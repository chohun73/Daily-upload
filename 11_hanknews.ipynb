# %% [markdown]
# - 당일 기사 전체를 다 가져오는 것
# 1. 클릭해서 들어가는것 구현

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=015&listType=paper&date=20240606&page=1'
html_doc = requests.get(url).text
html_doc
# Out:
# '\r\n\r\n\r\n\r\n<!DOCTYPE HTML>\r\n<html lang="ko">\r\n<head>\r\n<meta charset="euc-kr">\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n<meta name="referrer" contents="always">\r\n<meta http-equiv="refresh" content="600" />\r\n<meta name="viewport" content="width=1106" />\r\n\r\n    \r\n    \r\n        \r\n            \r\n            \r\n            \r\n                \r\n                \r\n                \r\n                \r\n            \r\n            \r\n            \r\n            \r\n        \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n\r\n<meta property="og:title"       content="한국경제 언론사홈">\r\n<meta property="og:type"        content="website">\r\n<meta property="og:url"         content="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=015">\r\n<meta property="og:image"       content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_2022120
# ...

# %%
soup = BeautifulSoup(html_doc,'html.parser')
soup
# Out:
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh">
# <meta content="width=1106" name="viewport">
# <meta content="한국경제 언론사홈" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=015" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image">
# <meta content="언론사 주요 뉴스와 속보를 만나볼 수 있습니다." property="og:description"/>
# <meta content="네이버" property="og:article:author">
# <meta content="summary" name="twitter:card"/>
# <meta content="한국경제 언론사홈" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# ...

# %%
box_contents = soup.find_all('a',class_='nclicks(cnt_papaerart4)')
box_contents
# Out:
# [<a class="nclicks(cnt_papaerart4)" href="https://n.news.naver.com/mnews/article/015/0004993601">한국 1인당 국민소득, 사상 처음 日 앞섰다…이유 알고보니</a>,
#  <a class="nclicks(cnt_papaerart4)" href="https://n.news.naver.com/mnews/article/015/0004993586">5000억 인쇄소…아날로그의 부활</a>,
#  <a class="nclicks(cnt_papaerart4)" href="https://n.news.naver.com/mnews/article/015/0004993598">'범삼성家' 신세계-CJ 뭉쳤다…정용진 '윈윈' 승부수 뭐길래</a>,
#  <a class="nclicks(cnt_papaerart4)" href="https://n.news.naver.com/mnews/article/015/0004993599">"한국 '화장지 대란' 일어날 수도 있다"…경고 나온 까닭</a>,
#  <a class="nclicks(cnt_papaerart4)" href="https://n.news.naver.com/mnews/article/015/0004993617">뉴욕에 도전장…美 텍사스 증권거래소 추진</a>,
#  <a class="nclicks(cnt_papaerart4)" href="https://n.news.naver.com/mnews/article/015/0004993614">과도한 검열…中 웹사이트 70% 줄었다</a>,
#  <a class="nclicks(cnt_papaerart4)" href="https://n.news.naver.com/mnews/article/015/0004993615">[이 아침의 배우] 韓영화계 최연소 1억 배우…하정우</a>,
# ...

# %%
len(box_contents)
# Out:
# 33

# %%
box_contents[0]
# Out:
# <a class="nclicks(cnt_papaerart4)" href="https://n.news.naver.com/mnews/article/015/0004993601">한국 1인당 국민소득, 사상 처음 日 앞섰다…이유 알고보니</a>

# %%
url =box_contents[0]['href']
url
# Out:
# 'https://n.news.naver.com/mnews/article/015/0004993601'

# %%
title = box_contents[0].find('a', class_='nclicks(cnt_papaerart4)').text
title
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 title = box_contents[0].find('a', class_='nclicks(cnt_papaerart4)').text
#       2 title
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# # Robots.txt 로 검색해본 결과.
#
# - 한국경제, 매일경제는 크롤링을 사이트 전체에서 막아놔서 더이상 실습이 불가능하다고 판단.
# - 요즘IT, KBS, MBC는 가능
